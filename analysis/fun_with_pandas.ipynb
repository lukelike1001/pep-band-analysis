# %% [markdown]
# **Fun with Pandas**<br>
# Demonstrating how to use pd.DataFrames with pandas.

# %%
import pandas as pd

# %%
pep_band_df = pd.read_csv("../data/cumulative/DUMB Pep Band Song Statistics - Cumulative.csv")

# %%
pep_band_df
# Out:
#     Date    Opponent Type                    Song    Period   Media   Time  \
# 0    2/7  Notre Dame  MBB                Overpass   Pregame     NaN    NaN
# 1    NaN         NaN  NaN         About Damn Time   Pregame     NaN    NaN
# 2    NaN         NaN  NaN                  Animal   Pregame     NaN    NaN
# 3    NaN         NaN  NaN                 Vehicle   Pregame     NaN    NaN
# 4    NaN         NaN  NaN  Potential Breakup Song   Pregame     NaN    NaN
# ..   ...         ...  ...                     ...       ...     ...    ...
# 320  NaN         NaN  NaN                   Devil        2H  <12:00  11:39
# 321  NaN         NaN  NaN      That's What I Want        2H  <12:00  11:39
# 322  NaN         NaN  NaN               Everytime        2H     NaN   8:19
# 323  NaN         NaN  NaN                    Sail        2H   <4:00   1:39
# 324  NaN         NaN  NaN            Blue & White  Postgame     NaN    NaN
#
#     Score (Duke-Opponent) Early? (Y/N)
# ...

# %%
pep_band_df.dtypes
# Out:
# Date                     object
# Opponent                 object
# Type                     object
# Song                     object
# Period                   object
# Media                    object
# Time                     object
# Score (Duke-Opponent)    object
# Early? (Y/N)             object
# dtype: object

# %%
# Option 1: Set the index to the song name
# pep_band_song_series = pep_band_df.groupby("Song").size()
# song_column_names = ["Count"]

# pep_band_song_df = pd.DataFrame(pep_band_song_series, columns=song_column_names)

# Option 2: Set the index to the group key
pep_band_song_series = pep_band_df.groupby("Song").size().reset_index(name="Count")
pep_band_song_df = pd.DataFrame(pep_band_song_series)

# %%
pep_band_song_df.index
# Out:
# RangeIndex(start=0, stop=46, step=1)

# %%
pep_band_song_df
# Out:
#                         Song  Count
# 0            About Damn Time      4
# 1                     Animal      1
# 2               Blue & White     35
# 3           Break Your Heart      2
# 4                      Can't     33
# 5                  Chameleon      1
# 6              Crazy in Love      1
# 7                   D. Ditty      3
# 8                    DJamite      3
# 9            Dance the Night     11
# 10             Dear Old Duke      9
# 11                     Devil     24
# 12                 Disturbia      1
# 13                 Everytime     13
# 14                       Fat      2
# 15               Fight Fight     22
# 16                      Fire      1
# 17                 Get It On      1
# 18              Igor's Theme      1
# 19             Industry Baby      1
# 20             Love Runs Out      3
# 21  Love from the Other Side     10
# 22              Lucky Strike      7
# 23                    Mortal      8
# 24               Ms. Jackson      1
# ...

# %%
pd.DataFrame({"num": [pep_band_song_df["Count"].max()]})
# Out:
#    num
# 0   35
